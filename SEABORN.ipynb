# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly as px
import seaborn as sns

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=tips , x='total_bill' , y ='tip', hue ='sex', style='time',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
sns.relplot (data=tips, x='total_bill',y='tip',kind = 'scatter',hue ='sex',style='time',size = 'size')

# %%
#lineplot
gap=px.data.gapminder()
temp_df=gap[gap['country']=='India']
temp_df
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# 697      356
# 698      356
# 699      356
# 700      356
# 701      356
# 702      356
# 703      356
# 704      356
# 705      356
# 706      356
# 707      356

# %%
dz=pd.read_csv('/content/IRIX_stock_data.csv')
dz
# Out:
#       Unnamed: 0    open   high    low  close  adjclose   volume ticker
# 0     1996-02-16  11.000  11.00  10.00  10.25     10.25  2256700   IRIX
# 1     1996-02-20  10.000  10.50  10.00  10.00     10.00   162200   IRIX
# 2     1996-02-21  10.250  10.25   9.75   9.75      9.75   147300   IRIX
# 3     1996-02-22   9.750  10.25   9.75  10.00     10.00   286800   IRIX
# 4     1996-02-23  10.125  10.75  10.00  10.75     10.75    55300   IRIX
# ...          ...     ...    ...    ...    ...       ...      ...    ...
# 7128  2024-06-13   2.100   2.18   2.09   2.14      2.14    30300   IRIX
# 7129  2024-06-14   2.100   2.26   2.08   2.10      2.10    52900   IRIX
# 7130  2024-06-17   2.150   2.18   2.08   2.10      2.10    18200   IRIX
# 7131  2024-06-18   2.140   2.14   1.89   1.98      1.98    37800   IRIX
# 7132  2024-06-20   1.990   1.99   1.94   1.97      1.97    23900   IRIX
#
# [7133 rows x 8 columns]

# %%
dz.drop_duplicates()
# Out:
#       Unnamed: 0    open   high    low  close  adjclose   volume ticker
# 0     1996-02-16  11.000  11.00  10.00  10.25     10.25  2256700   IRIX
# 1     1996-02-20  10.000  10.50  10.00  10.00     10.00   162200   IRIX
# 2     1996-02-21  10.250  10.25   9.75   9.75      9.75   147300   IRIX
# 3     1996-02-22   9.750  10.25   9.75  10.00     10.00   286800   IRIX
# 4     1996-02-23  10.125  10.75  10.00  10.75     10.75    55300   IRIX
# ...          ...     ...    ...    ...    ...       ...      ...    ...
# 7128  2024-06-13   2.100   2.18   2.09   2.14      2.14    30300   IRIX
# 7129  2024-06-14   2.100   2.26   2.08   2.10      2.10    52900   IRIX
# 7130  2024-06-17   2.150   2.18   2.08   2.10      2.10    18200   IRIX
# 7131  2024-06-18   2.140   2.14   1.89   1.98      1.98    37800   IRIX
# 7132  2024-06-20   1.990   1.99   1.94   1.97      1.97    23900   IRIX
#
# [7133 rows x 8 columns]

# %%
dz.describe()
# Out:
#               open         high          low        close     adjclose  \
# count  7133.000000  7133.000000  7133.000000  7133.000000  7133.000000
# mean      5.909981     6.059806     5.759999     5.911738     5.911738
# std       3.237308     3.302808     3.167423     3.239440     3.239440
# min       0.520000     0.580000     0.360000     0.550000     0.550000
# 25%       3.480000     3.580000     3.390000     3.500000     3.500000
# 50%       5.000000     5.150000     4.875000     5.000000     5.000000
# 75%       8.200000     8.375000     8.000000     8.210000     8.210000
# max      18.250000    18.500000    16.500000    17.000000    17.000000
#
#              volume
# count  7.133000e+03
# mean   3.497805e+04
# std    1.617033e+05
# min    0.000000e+00
# 25%    5.200000e+03
# 50%    1.440000e+04
# 75%    3.310000e+04
# max    1.068360e+07

# %%
sns.lineplot(data=dz,x='high',y='low')
# Out:
# <Axes: xlabel='high', ylabel='low'>

# %%
sns.scatterplot(data=dz,x='high',y='low')
# Out:
# <Axes: xlabel='high', ylabel='low'>

# %%
#axes leve function

sns.lineplot(data=temp_df,x='year',y='lifeExp')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
sns.pairplot(tips)
plt.show()

# %%
temp_df = gap[gap['country'].isin(['India','Brazil','Germany'])]
temp_df
# Out:
#      country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 168   Brazil  Americas  1952   50.917    56602560   2108.944355       BRA
# 169   Brazil  Americas  1957   53.285    65551171   2487.365989       BRA
# 170   Brazil  Americas  1962   55.665    76039390   3336.585802       BRA
# 171   Brazil  Americas  1967   57.632    88049823   3429.864357       BRA
# 172   Brazil  Americas  1972   59.504   100840058   4985.711467       BRA
# 173   Brazil  Americas  1977   61.489   114313951   6660.118654       BRA
# 174   Brazil  Americas  1982   63.336   128962939   7030.835878       BRA
# 175   Brazil  Americas  1987   65.205   142938076   7807.095818       BRA
# 176   Brazil  Americas  1992   67.057   155975974   6950.283021       BRA
# 177   Brazil  Americas  1997   69.388   168546719   7957.980824       BRA
# 178   Brazil  Americas  2002   71.006   179914212   8131.212843       BRA
# 179   Brazil  Americas  2007   72.390   190010647   9065.800825       BRA
# 564  Germany    Europe  1952   67.500    69145952   7144.114393       DEU
# 565  Germany    Europe  1957   69.100    71019069  10187.826650       DEU
# 566  Germany    Europe  1962   70.300    73739117  12902.462910       DEU
# 567  Germany    Europe  1967   70.800    76368453  14745.625610       DEU
# 568  Germany    Europe  1972   71.000    78717088  18016.180270       DEU
# 569  Germany    Europe  1977   72.500    78160773  20512.921230       DEU
# 570  Germany    Europe  1982   73.800    78335266  22031.532740       DEU
# 571  Germany    Europe  1987   74.847    77718298  24639.185660       DEU
# 572  Germany    Europe  1992   76.070    80597764  26505.303170       DEU
# 573  Germany    Europe  1997   77.340    82011073  27788.884160       DEU
# 574  Germany    Europe  2002   78.670    82350671  30035.801980       DEU
# 575  Germany    Europe  2007   79.406    82400996  32170.374420       DEU
# 696    India      Asia  1952   37.373   372000000    546.565749       IND
# 697    India      Asia  1957   40.249   409000000    590.061996       IND
# 698    India      Asia  1962   43.605   454000000    658.347151       IND
# 699    India      Asia  1967   47.193   506000000    700.770611       IND
# 700    India      Asia  1972   50.651   567000000    724.032527       IND
# 701    India      Asia  1977   54.208   634000000    813.337323       IND
# 702    India      Asia  1982   56.596   708000000    855.723538       IND
# 703    India      Asia  1987   58.553   788000000    976.512676       IND
# 704    India      Asia  1992   60.223   872000000   1164.406809       IND
# 705    India      Asia  1997   61.765   959000000   1458.817442       IND
# 706    India      Asia  2002   62.879  1034172547   1746.769454       IND
# 707    India      Asia  2007   64.698  1110396331   2452.210407       IND
#
#      iso_num
# 168       76
# 169       76
# 170       76
# 171       76
# 172       76
# 173       76
# 174       76
# 175       76
# 176       76
# 177       76
# 178       76
# 179       76
# 564      276
# 565      276
# 566      276
# 567      276
# 568      276
# 569      276
# 570      276
# 571      276
# 572      276
# 573      276
# 574      276
# 575      276
# 696      356
# 697      356
# 698      356
# 699      356
# 700      356
# 701      356
# 702      356
# 703      356
# 704      356
# 705      356
# 706      356
# 707      356

# %%
#EDA  EPLORATORY DATA ANALYSIS

# %%
sns.relplot(kind='line',data=temp_df,x='year',y='lifeExp',hue='country',style='continent',size='continent')
plt.grid()

# %%
sns.pairplot(temp_df)
plt.show()

# %%
sns.relplot(data=tips, x='total_bill', y='tip', kind='line', col='sex', row='day')
#replplot means linegraph

# %%
sns.histplot(data=tips, x='total_bill')
plt.grid()

# %%
sns.displot(data=tips, x='total_bill',kind='hist',bins=50)
plt.grid()

# %%
#col wrap

sns.relplot(data=gap , x=)

# %%
import numpy as np
#heatmap

plt.figure(figsize=(12,12))
sns.heatmap(tips.select_dtypes(include=np.number))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_648/3628582339.py in <cell line: 0>()
#       2
#       3 plt.figure(figsize=(12,12))
# ----> 4 sns.heatmap(tips)
#
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     444     """
#     445     # Initialize the plotter object
# --> 446     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                           annot_kws, cbar, cbar_kws, xticklabels,
#     448                           yticklabels, mask)
#
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     161
#     162         # Determine good default values for the colormapping
# --> 163         self._determine_cmap_params(plot_data, vmin, vmax,
#     164                                     cmap, center, robust)
#     165
#
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py in _determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     195
#     196         # plot_data is a np.ma.array instance
# --> 197         calc_data = plot_data.astype(float).filled(np.nan)
#     198         if vmin is None:
#     199             if robust:
#
# ValueError: could not convert string to float: 'Female'
