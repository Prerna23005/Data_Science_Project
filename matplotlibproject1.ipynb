# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/archive (4).zip')
df
# Out:
#             Date          Open          High           Low         Close  \
# 0     2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1     2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3     2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4     2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...          ...           ...           ...           ...           ...
# 4275  2026-06-01  73580.210938  73969.570312  70599.507812  71319.773438
# 4276  2026-06-02  71321.031250  71334.953125  66127.265625  66703.656250
# 4277  2026-06-03  66694.007812  67402.929688  64009.675781  64014.367188
# 4278  2026-06-04  64020.070312  64664.445312  61335.750000  63801.574219
# 4279  2026-06-05  63807.691406  63901.515625  59108.917969  60922.667969
#
#          Adj Close       Volume
# 0       457.334015     21056800
# ...

# %%
df.shape
# Out:
# (4280, 7)

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#             Date          Open          High           Low         Close  \
# 0     2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1     2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3     2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4     2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...          ...           ...           ...           ...           ...
# 4275  2026-06-01  73580.210938  73969.570312  70599.507812  71319.773438
# 4276  2026-06-02  71321.031250  71334.953125  66127.265625  66703.656250
# 4277  2026-06-03  66694.007812  67402.929688  64009.675781  64014.367188
# 4278  2026-06-04  64020.070312  64664.445312  61335.750000  63801.574219
# 4279  2026-06-05  63807.691406  63901.515625  59108.917969  60922.667969
#
#          Adj Close       Volume
# 0       457.334015     21056800
# ...

# %%
df.shape
# Out:
# (4280, 7)

# %%
df.describe()
# Out:
#                 Open           High            Low          Close  \
# count    4280.000000    4280.000000    4280.000000    4280.000000
# mean    28623.330630   29188.324150   28019.749124   28636.451670
# std     32442.204251   32986.012544   31852.792883   32442.454923
# min       176.897003     211.731003     171.509995     178.102997
# 25%      3452.187439    3504.092224    3391.943420    3458.813721
# 50%     11536.727539   11850.328613   11288.414062   11564.331543
# 75%     46401.472656   47432.591797   45184.174805   46446.924805
# max    124752.140625  126198.070312  123196.046875  124752.531250
#
#            Adj Close        Volume
# count    4280.000000  4.280000e+03
# mean    28636.451670  2.230348e+10
# std     32442.454923  2.294359e+10
# min       178.102997  5.914570e+06
# 25%      3458.813721  1.676575e+09
# 50%     11564.331543  1.802679e+10
# 75%     46446.924805  3.446429e+10
# max    124752.531250  3.509679e+11

# %%
plt.figure(figsize=(50,10))
plt.xlabel('Date')
plt.ylabel('Close')
plt.grid(True)
plt.title('Date vs Close')
plt.plot(df['Date'],df['Close'])
plt.show()

# %%
plt.figure(figsize=(50,10))
 #plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Close')

plt.title('Date vs Close')
plt.scatter(df['Date'],df['Close'])
plt.show()

# %%
 #plt.grid(True)
 #plt.xlabel('Date')
 #plt.ylabel('Close')

 #plt.title('Date vs Close')
plt.pie(df['High'])
plt.show()

# %%
df.sample()
# Out:
#             Date          Open         High           Low         Close  \
# 3198  2023-06-20  26841.664062  28388.96875  26668.791016  28327.488281
#
#          Adj Close       Volume
# 3198  28327.488281  22211859147

# %%
#plt.scatter simple fucntion

x=np.linspace(-10,10,50)
y=10*x + 3+ np.random.randint(0,300,50)
y
# Out:
# array([139.        , 196.08163265,  93.16326531, 169.24489796,
#        144.32653061,  72.40816327,  76.48979592, 111.57142857,
#         71.65306122,  31.73469388, 200.81632653, 200.89795918,
#        -16.02040816,  71.06122449,   7.14285714, 167.2244898 ,
#        222.30612245,   2.3877551 ,  45.46938776, 261.55102041,
#         17.63265306,  55.71428571, 261.79591837,  67.87755102,
#         42.95918367, 149.04081633, 205.12244898, 299.20408163,
#         45.28571429, 260.36734694, 123.44897959, 281.53061224,
#         53.6122449 , 180.69387755, 107.7755102 , 202.85714286,
#        336.93877551, 289.02040816, 294.10204082,  78.18367347,
#        242.26530612, 240.34693878, 316.42857143,  86.51020408,
#        194.59183673, 269.67346939, 211.75510204, 155.83673469,
#        191.91836735, 282.        ])

# %%
plt.scatter(x,y)
plt.show()

# %%
#plt.scatter on p
da=pd.read_csv('/content/batter_csv.csv')
da
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
plt.figure(figsize=(40,60))
plt.scatter(da['strike_rate'],da['batter'])
plt.title('batter vs strike rate')
plt.xlabel('strike rate')
plt.ylabel('batter')
# Out:
# Text(0, 0.5, 'batter')

# %%
da.describe()
# Out:
#               runs         avg  strike_rate
# count   605.000000  572.000000   605.000000
# mean    464.428099   15.912037   100.663928
# std     985.272855   10.487649    39.956350
# min       0.000000    0.000000     0.000000
# 25%      15.000000    7.729167    78.750000
# 50%      73.000000   14.421717   107.266436
# 75%     326.000000   23.041667   125.000000
# max    6634.000000   55.666667   400.000000

# %%
#simple bar chart

children = [10,20,40,10,30]
colors = ['red' , 'blue' , 'green','yellow','pink']

plt.bar(colors,children,color = 'red')
# Out:
# <BarContainer object of 5 artists>

# %%
#horozontal bar chart
children = [10,20,40,10,30]
colors = ['red' , 'blue' , 'green','yellow','pink']

plt.barh(colors,children,color = 'black')
# Out:
# <BarContainer object of 5 artists>

# %%
#barchart batsman

ds=pd.read_csv('/content/batsman_season_record.csv')
ds
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.figure(figsize=(10,10))
plt.bar(ds['batsman'],ds['2015'])
plt.bar(ds['batsman'],ds['2016'])
plt.bar(ds['batsman'],ds['2017'])
plt.xlabel('strike rate')
plt.ylabel('batter')
plt.show()
