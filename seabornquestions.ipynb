# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df=pd.read_csv('/content/index_2.csv')
df
# Out:
#            date             datetime cash_type  money  \
# 0    2025-02-08  2025-02-08 14:26:04      cash   15.0
# 1    2025-02-08  2025-02-08 14:28:26      cash   15.0
# 2    2025-02-08  2025-02-08 14:33:04      card   20.0
# 3    2025-02-08  2025-02-08 15:51:04      card   30.0
# 4    2025-02-08  2025-02-08 16:35:01      cash   27.0
# ..          ...                  ...       ...    ...
# 257  2025-03-23  2025-03-23 14:55:46      cash   30.0
# 258  2025-03-23  2025-03-23 15:15:36      card   25.0
# 259  2025-03-23  2025-03-23 17:59:25      card   28.0
# 260  2025-03-23  2025-03-23 18:01:33      card   28.0
# 261  2025-03-23  2025-03-23 21:23:11      card   29.0
#
#                     coffee_name
# 0                           Tea
# 1                           Tea
# 2                      Espresso
# 3         Chocolate with coffee
# 4           Chocolate with milk
# ..                          ...
# 257                  Cappuccino
# 258               Irish whiskey
# ...

# %%
df.drop_duplicates().sum()
# Out:
# date           2025-02-082025-02-082025-02-082025-02-082025-0...
# datetime       2025-02-08 14:26:042025-02-08 14:28:262025-02-...
# cash_type      cashcashcardcardcashcardcashcashcardcashcashca...
# money                                                     6840.0
# coffee_name    TeaTeaEspressoChocolate with coffeeChocolate w...
# dtype: object

# %%
df.shape()
# Out:
# (262, 5)

# %%
df.describe()
# Out:
#            money
# count  262.00000
# mean    26.29771
# std      4.25021
# min     15.00000
# 25%     25.00000
# 50%     27.00000
# 75%     29.00000
# max     33.00000

# %%
sns.barplot(data=df,x='coffee_name',y='date')
plt.xlabel('coffee_name')
plt.ylabel('date')
plt.title('best selling product')
plt.grid()
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_3503/1776501596.py:6: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.scatterplot(data=df,x='coffee_name',y='date')
plt.xlabel('coffee_name')
plt.ylabel('date')
plt.title('best selling product')
plt.grid()
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_3503/1362867689.py:6: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df.iloc[4:8]
# Out:
#          date             datetime cash_type  money                coffee_name
# 4  2025-02-08  2025-02-08 16:35:01      cash   27.0        Chocolate with milk
# 5  2025-02-08  2025-02-08 18:55:30      card   33.0                   Espresso
# 6  2025-02-08  2025-02-08 18:59:03      cash   29.0  Coffee with Irish whiskey
# 7  2025-02-08  2025-02-08 19:00:28      cash   27.0    Irish whiskey with milk

# %%
df=df.sort_values(by='money',ascending=False)
df
# Out:
#            date             datetime cash_type  money coffee_name
# 235  2025-03-19  2025-03-19 17:44:09      cash   33.0       Latte
# 238  2025-03-20  2025-03-20 11:54:23      card   33.0       Latte
# 223  2025-03-17  2025-03-17 16:44:56      card   33.0       Latte
# 50   2025-02-16  2025-02-16 16:36:54      card   33.0       Latte
# 194  2025-03-12  2025-03-12 07:53:08      card   33.0       Latte
# ..          ...                  ...       ...    ...         ...
# 47   2025-02-15  2025-02-15 15:33:24      card   15.0         Tea
# 21   2025-02-09  2025-02-09 18:01:22      card   15.0         Tea
# 27   2025-02-11  2025-02-11 09:49:22      card   15.0         Tea
# 1    2025-02-08  2025-02-08 14:28:26      cash   15.0         Tea
# 0    2025-02-08  2025-02-08 14:26:04      cash   15.0         Tea
#
# [262 rows x 5 columns]

# %%
df.head(5)
# Out:
#            date             datetime cash_type  money coffee_name
# 235  2025-03-19  2025-03-19 17:44:09      cash   33.0       Latte
# 238  2025-03-20  2025-03-20 11:54:23      card   33.0       Latte
# 223  2025-03-17  2025-03-17 16:44:56      card   33.0       Latte
# 50   2025-02-16  2025-02-16 16:36:54      card   33.0       Latte
# 194  2025-03-12  2025-03-12 07:53:08      card   33.0       Latte

# %%
df['money'].max()
# Out:
# 33.0

# %%
sns.heatmap(df.corr(numeric_only=True))
plt.show()

# %% [markdown]
# covid-19

# %%
dz=pd.read_csv('/content/Latest Covid-19 India Status.csv')
dz
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
dz.drop_duplicates()
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
dz.shape
# Out:
# (36, 9)

# %%
dz.isnull().sum()
# Out:
# State/UTs          0
# Total Cases        0
# Active             0
# Discharged         0
# Deaths             0
# Active Ratio       0
# Discharge Ratio    0
# Death Ratio        0
# Population         0
# dtype: int64

# %%
sns.barplot(data=dz,x='State/UTs',y='Total Cases')
plt.xlabel('State/UTs')
plt.ylabel('Total Cases')
plt.title('State wise cases')
plt.grid()
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_3503/181562854.py:6: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.barplot(data=dz,x='Discharge Ratio',y='Death Ratio')
plt.xlabel('Discharge Ratio')
plt.ylabel('Death Ratio')
plt.title('recovery vs death rates')
plt.grid()
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_3503/4172902509.py:6: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.scatterplot(data=dz,x='Discharge Ratio',y='Death Ratio')
plt.xlabel('Discharge Ratio')
plt.ylabel('Death Ratio')
plt.title('recovery vs death rates')
plt.grid()
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_3503/2642302442.py:6: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.scatterplot(data=dz,x='State/UTs',y='Total Cases')
plt.xlabel('State/UTs')
plt.ylabel('Total Cases')
plt.title('State wise cases')
plt.grid()
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_3503/3005117907.py:6: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.heatmap(dz.corr(numeric_only=True))
plt.show()

# %%
sns.pairplot(dz)
plt.show()

# %%
sns.pairplot(df)
plt.show()
