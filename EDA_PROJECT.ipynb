# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv('/content/loan_approval_dataset.csv')
df
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
df.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4264    False
# 4265    False
# 4266    False
# 4267    False
# 4268    False
# Length: 4269, dtype: bool

# %%
df.shape
# Out:
# (4269, 13)

# %%
df.size
# Out:
# 55497

# %%
df.drop_duplicates()
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
df.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4269.000000        4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000           2.498712   5.059124e+06  1.513345e+07
# std    1232.498479           1.695910   2.806840e+06  9.043363e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000           1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000           3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000           4.000000   7.500000e+06  2.150000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# ...

# %%
df[' income_annum'].max()
# Out:
# 9900000

# %%
df[' cibil_score'].sort_values()
# Out:
# 3038    300
# 1404    300
# 95      300
# 3190    300
# 1776    300
#        ...
# 2473    900
# 821     900
# 373     900
# 3621    900
# 1867    900
# Name:  cibil_score, Length: 4269, dtype: int64

# %%
df[' loan_amount'].sort_values()
# Out:
# 2752      300000
# 3324      300000
# 2322      300000
# 1866      300000
# 674       300000
#           ...
# 1308    38500000
# 1027    38700000
# 1634    38700000
# 258     38800000
# 509     39500000
# Name:  loan_amount, Length: 4269, dtype: int64

# %%
df[' loan_amount'].sort_index()
# Out:
# 0       29900000
# 1       12200000
# 2       29700000
# 3       30700000
# 4       24200000
#           ...
# 4264     2300000
# 4265    11300000
# 4266    23900000
# 4267    12800000
# 4268    29700000
# Name:  loan_amount, Length: 4269, dtype: int64

# %%
plt.figure(figsize=(10,10))
plt.bar(df[' loan_term'],df[' loan_status'])
plt.xlabel('loan_term')
plt.ylabel('loan_status')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.scatter(df[' loan_term'],df[' loan_status'])
plt.xlabel('loan_term')
plt.ylabel('loan_status')
plt.show()

# %%
dz=pd.read_csv('/content/shopping_trends.csv')
dz
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
dz.drop_duplicates()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
dz['Gender'].max()
# Out:
# 'Male'

# %%
dz['Item Purchased'].max()
# Out:
# 'T-shirt'

# %%
dz['Item Purchased'].min()
# Out:
# 'Backpack'

# %%
dz.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
plt.figure(figsize=(10,10))
plt.bar(dz['Item Purchased'],dz['Category'])
plt.xlabel('Item Purchased')
plt.xticks(rotation=90)
plt.yticks(rotation=90)
plt.ylabel('Category')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.bar(dz['Gender'],dz['Category'])
plt.xlabel('Gender')
plt.xticks(rotation=90)
plt.yticks(rotation=90)
plt.ylabel('Category')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.bar(dz['Gender'],dz['Item Purchased'])
plt.xlabel('Gender')
plt.xticks(rotation=90)
#plt.yticks(rotation=90)
plt.ylabel('Item Purchased')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.bar(dz['Category'],dz['Item Purchased'])
plt.xlabel('Category')
plt.xticks(rotation=90)
#plt.yticks(rotation=90)
plt.ylabel('Item Purchased')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.scatter(dz['Category'],dz['Item Purchased'])
plt.xlabel('Category')
plt.xticks(rotation=90)
#plt.yticks(rotation=90)
plt.ylabel('Item Purchased')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.scatter(dz['Frequency of Purchases'],dz['Item Purchased'])
plt.xlabel('Frequency of Purchases')
plt.xticks(rotation=90)
#plt.yticks(rotation=90)
plt.ylabel('Item Purchased')
plt.show()
